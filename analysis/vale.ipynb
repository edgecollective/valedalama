# %%
import pandas as pd
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
a=pd.read_csv("./latest.csv")

# %%
a.columns=['date','field','value']

# %%
a.set_index("field",inplace=True)

# %%
a.head()
# Out:
#                                 date        value
# field
# remote_e_raw      11/10/2019 - 06:49  4095.000000
# remote_soil_temp  11/10/2019 - 06:49    20.900000
# gateway_pressure  11/10/2019 - 06:49  1023.820000
# remote_ec_raw     11/10/2019 - 06:49     0.000000
# remote_vwc        11/10/2019 - 06:49     0.497181

# %%
d = a.loc["remote_ec_raw"]; v = a.loc["remote_soil_capacitive"]

# %%
fig, ax = subplots()
fig.set_size_inches(15, 6)
#fig(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#ax.xticks(rotation=70)
h.plot(x='date',y='value',ax=ax,x_compat=True)
v.plot(x='date',y='value',ax=ax,x_compat=True)
plt.xticks(rotation=86)
plt.ylabel("meters", labelpad=20)
#ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#plt.gcf().autofmt_xdate()
#ax.legend(['water level (m)'])
ax.xaxis.labelpad = 20
#hours = mdates.HourLocator(interval = 1)
#h_fmt = mdates.DateFormatter('%H:%M:%S')
#ax.xaxis.set_major_locator(hours)
#ax.xaxis.set_major_formatter(h_fmt)
#fig.autofmt_xdate()
#plt.show()
#ax.xaxis.set_major_locator(mdates.HourLocator(interval=1))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
#plt.gcf().autofmt_xdate()
#plt.show()
#plt.axhline(y=1.6, color='r', linestyle='-')
#plt.axhline(y=1.7, color='r', linestyle='-')
#plt.axhline(y=1.98, color='r', linestyle='-')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-217392d0405b> in <module>
#       3 #fig(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
#       4 #ax.xticks(rotation=70)
# ----> 5 h.plot(x='date',y='value'/150.,ax=ax,x_compat=True)
#       6 v.plot(x='date',y='value',ax=ax,x_compat=True)
#       7 plt.xticks(rotation=86)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# try this next: https://stackoverflow.com/questions/48790378/how-to-get-ticks-every-hour

# %%
xd=d.values[:,1]/150.

# %%
plot(xd)

# %%
xv=v.values[:,1]/2.55

# %%
plot(xv)

# %%
plot(xd,label='remote_ec_raw / 150');plot(xv,label='remote_soil_capacitive / 2.55');ylim(.9,1.1);xlim(1200,1400);legend()

# %%
plot(d.values[:,1]);title("remote_ec_raw")
# Out:
# Text(0.5,1,'remote_ec_raw')

# %%
plot(v.values[:,1]);title('remote_soil_capacitive')
# Out:
# Text(0.5,1,'remote_soil_capacitive')
